# %%
# !pip install findspark
# Out:
# Requirement already satisfied: findspark in c:\users\farhan\anaconda3\lib\site-packages (2.0.1)

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, split

spark = SparkSession.builder.appName("TestApp").getOrCreate()
print("Spark session started successfully")
# Out:
# Spark session started successfully

# %%
input_file=r"C:\Users\farhan\OneDrive\Desktop\input.txt"
df=spark.read.text(input_file)
word_count = (df.select(explode(split(df.value, " ")).alias("word")).groupBy("word").count())
word_count.show()
# Out:
# +------+-----+
# |  word|count|
# +------+-----+
# | hello|    2|
# |    is|    1|
# |  file|    1|
# |sample|    1|
# | world|    1|
# |     a|    1|
# |  this|    1|
# +------+-----+

# %%
# !python --version
# Out:
# Python 3.12.7
